# %% [raw]
# 1. Make a list of the mobile numbers and pass it to a function that sorts the array in ascending order. Make a decorator that
# standardizes the mobile numbers and apply it to the function.The given mobile numbers may have +91 , 91 or  0 written
# before the actual  digit number. Alternatively, there may not be any prefix at all.
#
# Input Format
# The first line of input contains an integer , the number of mobile phone numbers.
# N lines follow each containing a mobile number.
# Output Format
# Print  N mobile numbers on separate lines in the required format.
#
# Sample Input
# 07895462130
# 919875641230
# 9195969878
#
# Sample Output
# +91 78954 62130
# +91 91959 69878
# +91 98756 41230

# %%
list1=[8798876545,417823456789,7623456789,4156789854,7517094567,917765437887,7986544332,915820367,9256778888,93466666666,9456327876,9525637188,9665840845,9798877278,9890202016,9967086180]

# %%
b = [8798876545,417823456789,7623456789,4156789854,7517094567,917765437887,7986544332,915820367,9256778888,93466666666,9456327876,9525637188,9665840845,9798877278,9890202016,9967086180]

# %%
li=[]
def dec(list1)
  while list1:
        min = list1[0]  
        for x in list1: 
            if x < min:
                min = x
        li.append(min)
        list1.remove(min)    
    print(li)

# %%
def mobile(function):
    def input(li):
            return sorted([function(i) for i in li])
    return input

# %%
@mobile
def standardize(li):
    return "+91" + " " +li[-10:-5] + " " +li[-5:]
print("\n".join(standardize(number))

# %%
def wrapper(f):
    def fun(li):
        f(['+91 ' + c[-10:-5] + ' ' + c[-5:] for c in li])      
    return fun

@wrapper
def sort_phone(li):
    print(*sorted(li), sep='\n')

if __name__ == '__main__':
    li = [input() for _ in range(int(input()))]
    sort_phone(li)

# %% [raw]
# 2. Let's use decorators to build a name directory! You are given some information about  people. Each person has a first name, last name, age and sex. Print their names in a specific format sorted by their age in ascending order i.e. the youngest person's name should be printed first. For two people of the same age, print them in the order of their input.
#
# For Henry Davids, the output should be:
# Mr. Henry Davids
#
# For Mary George, the output should be:
# Ms. Mary George
# Sample Input
# Mike Thomson 20 M
# Robert Bustle 32 M
# Andria Bustle 30 F
# Sample Output
# Mr. Mike Thomson
# Ms. Andria Bustle
# Mr. Robert Bustle

# %%
def person_lister(f):
    def inner(people):
        return map(f, sorted(people, key=lambda x: int(x[2])))
    return inner

@person_lister
def name_format(person):
    return ("Mr. " if person[3] == "M" else "Ms. ") + person[0] + " " + person[1]

if __name__ == '__main__':
    people = [input().split() for i in range(int(input()))]
    print(*name_format(people), sep='\n')

# %%
import operator
people = [input().split() for i in range(int(input()))]

# %%
def person_lister(f):
    def inner(people):
        return [f(person)for person sorted(people, key=oprator.itemgetter(2))]
    return inner

# %%
@person_lister
def name_format(person):
    return("Mr."if person[3]=="M" else "Ms. ")+person[0]+" "+person[1]
print(*name_format(people),sep='\n')

# %% [markdown]
# ![image.png](attachment:image.png)![image.png](attachment:image.png)

# %%
for i in range(int(input())):
    try
        a,b=map(int,input().spilt())
        print(a//b)
    except Exception as e:
        print()

# %%
try
   for i in range(0,2):
        print(i)
        2/0
except Exception as e:
    print("error code:",e)
